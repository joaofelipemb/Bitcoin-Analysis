# %% [markdown]
# # <b> Analyzing Bitcoin's Crash of 2022 </b>
# ### Written by João Felipe Maia Barbosa

# %% [markdown]
#
# *** Disclaimer: This is not an investment recommendation ***
#
# First of all, I would like to share to the reader that this is my first study, which I am very proud of and I hope you enjoy it.
#
# Analyzing financial markets can be tough since people take ideas too personal sometimes, and this is not my intent here.
#
# The purpose of this study is to share to the reader <b> my own thoughts </b> about the decline in value the Bitcoin and the cryptocurrency market had suffered in the first half of 2022. The study is splitted in 5 main parts. The first part is dedicated to understand the economic scenario during the pandemic and how it affected investors behavior toward risk. Next, I will be analyzing the reasons people were so interested in Bitcoin and the relevence social media has in the cryptocurrency markets. Then, this study will go over some technical factors such as price and volume analysis in order to understand the steep decline in June 2022. After that, I will be testing the argument crypto investors use to defend that Bitcoin can be used to diversify an investment portfolio. Finally, I will express my own opinions about the short-term and the long-term of the cryptocurrency market.
#
#
# The code is written in Python and the source of all the data used will be available throughout the study as the data is used.

# %%
# Packages used

import pandas as pd
import pandas_datareader as web
import numpy as np
import matplotlib as mpl
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt
import mplfinance as mpf
import seaborn as sns
from math import sqrt
import warnings


warnings.filterwarnings('ignore')
mpl.style.use('seaborn-darkgrid')

# %% [markdown]
# ## Part 1: The Economic Scenario and Risk Sentiment

# %% [markdown]
# The largest economies of the world were challenged during the COVID-19 pandemic. Because of lockdowns, companies had to shutdown their operations or send many of their workers away. That resulted in a massive unemployment rate and a economic fallout that was never seen before.

# %%
# U.S. Economic Data
us_gdp = pd.read_csv("GDP.csv", parse_dates=True, index_col="DATE").rename(columns={"A191RO1Q156NBEA" : 'Quarterly_GDP'})
us_unemployment_r = pd.read_csv("UNRATE.csv", parse_dates=True, index_col="DATE")

# %%
# Plotting data
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16, 8))

ax1.bar(us_gdp.index, us_gdp['Quarterly_GDP'], width=40)
ax1.set_title("U.S. Quaterly GDP (1950-2022)")
ax1.set_ylabel("Growth Rate")
ax1.annotate("Covid-19 Pandemic",
        xy=(0.83, 0.1), 
        xycoords='axes fraction',
        fontsize=10)

ax2.plot(us_unemployment_r['UNRATE'])
ax2.set_title("U.S. Unemployment Rate (1950-2022)")
ax2.set_ylabel("Unemployment Rate")
ax2.annotate("Covid-19 Pandemic",
        xy=(0.82, 0.9), 
        xycoords='axes fraction',
        fontsize=10)
# Out:
# Text(0.82, 0.9, 'Covid-19 Pandemic')

# %% [markdown]
# In order to stimulate the economy, the Central Banks around the world adopted a loose monetary policy, interest rates were reduced to record lows and many countries literally printed money to help their people, who couldn't go to work or were unemployed at that time.
#
# During lockdowns however, poeple were desperate to find new alternatives to generate income. One alternative people had found was trading stocks and cryptocurrencies.

# %%
# Importing Google Trends Data
stocks_crypto_trend = pd.read_csv("stocks_and_crypto.csv", parse_dates=True, index_col='Week' )

# %%
# Plotting Google Trends Data
fig, ax = plt.subplots(figsize=(20,8))

# Setting the plot data
ax.plot(stocks_crypto_trend['stocks'], label='Google Search Trend: "stocks"')
ax.plot(stocks_crypto_trend['crypto'], label = 'Google Search Trend: "crypto"')
ax.vlines(
        stocks_crypto_trend.index.to_frame().loc['3/8/2020'], 
        ymax=100, ymin=0, 
        color= 'red', 
        label="Covid-19 Pandemic Declared by WHO", 
        linestyle='solid')
ax.vlines(
        stocks_crypto_trend.index.to_frame().loc['4/5/2020'], 
        ymax=100, 
        ymin=0, 
        color= 'black', 
        label="USA sends the 1st stimulus check ($1,000)", linestyle='solid')
ax.legend()

None

# %% [markdown]
# Google Trends shows how frequently a given search term is entered into Google's search. It ranges from  0 to 100, where 0 shows the lowest volume in searches and 100 shows the highest volume in searches in a given period (2019 to 2022 in this case).
#
#
# The chart above shows the search trend for the words "stocks" and "crypto".
#
# The World Health Organization declared COVID-19 as pandamic in March 11th and we can see in the chart above the first signs of people looking for alternative ways of income.
# However, we can notice that, even though the interest for stocks during the first days of the COVID-19 rose, people didn't look very confortable to spend their money on risky assets since Stocks and Bitcoin were getting hammered during that period. As we can see below.

# %%
## Price data 2020

# Bicoin price data (During Pandemic)
btc_usd_pandemic = web.DataReader(
        'BTC-USD', 
        data_source='yahoo', 
        start='2019-06-23', 
        end='2020-06-08')['Adj Close'].to_frame().rename(columns={'Adj Close': 'BTCUSD'})

# SP500 price data (During Pandemic)
sp500_pandemic = web.DataReader(
        '^GSPC', 
        data_source='yahoo', 
        start='2019-06-23', 
        end='2020-06-08')['Adj Close'].to_frame().rename(columns={'Adj Close': 'SP500'})

# NASDAQ 100 price data (During Pandemic)
nasdaq_pandemic = web.DataReader(
        '^IXIC', 
        data_source='yahoo', 
        start='2019-06-23', 
        end='2020-06-08')['Adj Close'].to_frame().rename(columns={'Adj Close': 'NASDAQ100'})

# Prices dataframe
pandemic_df = pd.DataFrame([btc_usd_pandemic['BTCUSD'], sp500_pandemic['SP500'], nasdaq_pandemic['NASDAQ100']]).transpose().dropna()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(20,15))

# SP 500
ax1.plot(sp500_pandemic)
ax1.vlines(sp500_pandemic.index.to_frame().loc['3/10/2020'], ymax=3500, ymin=2000, color= 'red', label="Covid-19 Pandemic Declared by WHO", linestyle='solid')
ax1.vlines(sp500_pandemic.index.to_frame().loc['4/8/2020'], ymax=3500, ymin=2000, color= 'black', label="USA sends the 1st stimulus check ($1,000)", linestyle='solid')
ax1.legend()
ax1.set_ylabel("S&P 500")

# NASDAQ 100
ax2.plot(nasdaq_pandemic)
ax2.vlines(nasdaq_pandemic.index.to_frame().loc['3/10/2020'], ymax=10000, ymin=6000, color= 'red', label="Covid-19 Pandemic Declared by WHO", linestyle='solid')
ax2.vlines(nasdaq_pandemic.index.to_frame().loc['4/8/2020'], ymax=10000, ymin=6000, color= 'black', label="USA sends the 1st stimulus check ($1,000)", linestyle='solid')
ax2.set_ylabel("NASDAQ 100")

# Bitcoin
ax3.plot(btc_usd_pandemic)
ax3.vlines(btc_usd_pandemic.index.to_frame().loc['3/10/2020'], ymax=12500, ymin=2500, color= 'red', label="Covid-19 Pandemic Declared by WHO", linestyle='solid')
ax3.vlines(btc_usd_pandemic.index.to_frame().loc['4/8/2020'], ymax=12500, ymin=2500, color= 'black', label="USA sends the 1st stimulus check ($1,000)", linestyle='solid')
ax3.set_ylabel("Bitcoin")

None

# %% [markdown]
# It is important to remember that there was no way to know if risky assets were going to recover or were heading further down during that time. In addition, chances are that people were still scared about the massive declines in prices they experienced during the beginning of the pandemic.
#
# We can see the Drawdown for each asset below:

# %%
for asset in pandemic_df.columns:
    print(f'The Drawdown for {asset} during COVID-19 was: {format(((min(pandemic_df[asset]) / pandemic_df[asset].loc["2020-06-08"])-1)*100,".2f")}%')
# Out:
# The Drawdown for BTCUSD during COVID-19 was: -49.13%
# The Drawdown for SP500 during COVID-19 was: -30.78%
# The Drawdown for NASDAQ100 during COVID-19 was: -30.87%

# %% [markdown]
# However, people's behavior towards risk changed after they received the second and third stimulus check.
#
#
# I believe that as people realized that governments around the world, specially the U.S., were printing and distributing so much money, investors started to look for risky investments.
# As we can see in the chart below.

# %%
# Plotting Google Trends Data
fig, ax = plt.subplots(figsize=(20,10))

# Setting the plot data
ax.plot(stocks_crypto_trend['stocks'][20:120], 
    label='Google Search Trend: "stocks"')
ax.plot(stocks_crypto_trend['crypto'][20:120], 
    label = 'Google Search Trend: "crypto"')

# Plotting important events
ax.vlines(stocks_crypto_trend.index.to_frame().loc['3/8/2020'], 
        ymax=100, 
        ymin=0, 
        color= 'red', 
        label="Covid-19 Pandemic Declared by WHO", 
        linestyle='solid')
ax.vlines(stocks_crypto_trend.index.to_frame().loc['4/5/2020'], 
        ymax=100, 
        ymin=0, 
        color= 'black', 
        label="USA sends the 1st stimulus check ($1,000)", 
        linestyle='solid')
ax.vlines(stocks_crypto_trend.index.to_frame().loc['12/6/2020'], 
        ymax=100, 
        ymin=0, 
        color= 'black', 
        label="USA sends the 2nd stimulus check ($600)", 
        linestyle='dashdot')
ax.vlines(stocks_crypto_trend.index.to_frame().loc['3/7/2021'], 
        ymax=100, 
        ymin=0, 
        color= 'black', 
        label="USA sends the 3rd stimulus check($1,400)", 
        linestyle='dotted')

# Plot label
ax.set_ylabel("Search Interst Score")
ax.legend()

None

# %% [markdown]
# The search trend for stocks reached all time high after people received their second stimulus check. The search trend for "crypto" were also trending higher, but not as much as stocks. However, after people received their third stimulus check. The search trend for "crypto" exploded higher. In fact, the search frequency for crypto after the third stimulus check was higher than the frequency for stocks after the second stimulus check.
#
# Analyzing this data makes it clear that people were looking for risky assets. However, it also raises the following question: <b> Why were people so interested in cryptocurrencies? </b>

# %% [markdown]
# ## Part 2: Understanding People's Interest For Bitcoin and Cryptocurrencies

# %% [markdown]
# ### Price Analysis
# It is totally understandable that people would like to increase the risk of their portfolio during periods of easy money. However, that might not be the only reason people invested in Bitcoin and other cryptocurrencies.
#
# To have a deep understanding of that interest, let's take a look at the price chart for stocks and bitcoin one year after the pandemic.

# %%
## Price data - One year after pandemic

# Bicoin price data (During Pandemic)
btc_usd_pandemic_2nd = web.DataReader(
        'BTC-USD', 
        data_source='yahoo', 
        start='2020-02-23', 
        end='2021-04-08')['Adj Close'].to_frame().rename(columns={'Adj Close': 'BTCUSD'})

# SP500 price data (During Pandemic)
sp500_pandemic_2nd = web.DataReader(
        '^GSPC', 
        data_source='yahoo', 
        start='2020-02-23', 
        end='2021-04-08')['Adj Close'].to_frame().rename(columns={'Adj Close': 'SP500'})

# NASDAQ 100 price data (During Pandemic)
nasdaq_pandemic_2nd = web.DataReader(
        '^IXIC', 
        data_source='yahoo', 
        start='2020-02-23', 
        end='2021-04-08')['Adj Close'].to_frame().rename(columns={'Adj Close': 'NASDAQ100'})

# Prices dataframe
post_pandemic_df = pd.DataFrame([btc_usd_pandemic_2nd['BTCUSD'], sp500_pandemic_2nd['SP500'], nasdaq_pandemic_2nd['NASDAQ100']]).transpose().dropna()


# Calculating % Price increase
btc_usd_pandemic_2nd['%_Variation'] = (btc_usd_pandemic_2nd['BTCUSD'] / btc_usd_pandemic_2nd['BTCUSD'].iloc[0]) - 1
sp500_pandemic_2nd['%_Variation'] = (sp500_pandemic_2nd['SP500'] / sp500_pandemic_2nd['SP500'].iloc[0]) - 1
nasdaq_pandemic_2nd['%_Variation'] = (nasdaq_pandemic_2nd['NASDAQ100'] / nasdaq_pandemic_2nd['NASDAQ100'].iloc[0]) - 1

# %%
# Price data plot
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(20,15))

# SP 500
ax1.plot(sp500_pandemic_2nd['SP500'])
ax1.vlines(sp500_pandemic_2nd.index.to_frame().loc['3/10/2020'], 
        ymax=4000, 
        ymin=2300, 
        color= 'red', 
        label="Covid-19 Pandemic Declared by WHO", 
        linestyle='solid')
ax1.vlines(sp500_pandemic_2nd.index.to_frame().loc['4/8/2020'], 
        ymax=4000, 
        ymin=2300, 
        color= 'black', 
        label="USA sends the 1st stimulus check ($1,000)", 
        linestyle='solid')
ax1.vlines(sp500_pandemic_2nd.index.to_frame().loc['12/8/2020'], 
        ymax=4000, 
        ymin=2300, 
        color= 'black', 
        label="USA sends the 2nd stimulus check ($600)", 
        linestyle='dashdot')
ax1.vlines(sp500_pandemic_2nd.index.to_frame().loc['3/11/2021'], 
        ymax=4000, 
        ymin=2300, 
        color= 'black', 
        label="USA sends the 3rd stimulus check($1,400)", 
        linestyle='dotted')
ax1.legend()
ax1.set_ylabel("S&P 500")

# NASDAQ 100
ax2.plot(nasdaq_pandemic_2nd['NASDAQ100'])
ax2.vlines(nasdaq_pandemic_2nd.index.to_frame().loc['3/10/2020'], 
        ymax=14000, 
        ymin=7000, 
        color= 'red', 
        linestyle='solid')
ax2.vlines(nasdaq_pandemic_2nd.index.to_frame().loc['4/8/2020'], 
        ymax=14000, 
        ymin=7000, 
        color= 'black', 
        linestyle='solid')
ax2.vlines(nasdaq_pandemic_2nd.index.to_frame().loc['12/8/2020'], 
        ymax=14000, 
        ymin=7000, 
        color= 'black', 
        linestyle='dashdot')
ax2.vlines(nasdaq_pandemic_2nd.index.to_frame().loc['3/11/2021'], 
        ymax=14000, 
        ymin=7000, 
        color= 'black', 
        linestyle='dotted')
ax2.set_ylabel("NASDAQ 100")

# Bitcoin
ax3.plot(btc_usd_pandemic_2nd['BTCUSD'])
ax3.vlines(btc_usd_pandemic_2nd.index.to_frame().loc['3/10/2020'], 
        ymax=60000, 
        ymin=2500, 
        color= 'red', 
        linestyle='solid')
ax3.vlines(btc_usd_pandemic_2nd.index.to_frame().loc['4/8/2020'], 
        ymax=60000, 
        ymin=2500, 
        color= 'black', 
        linestyle='solid')
ax3.vlines(btc_usd_pandemic_2nd.index.to_frame().loc['12/8/2020'], 
        ymax=60000, 
        ymin=2000, 
        color= 'black', 
        linestyle='dashdot')
ax3.vlines(btc_usd_pandemic_2nd.index.to_frame().loc['3/11/2021'], 
        ymax=60000, 
        ymin=2500, 
        color= 'black', 
        linestyle='dotted')
ax3.set_ylabel("Bitcoin")

None

# %% [markdown]
# Although the price movements looks similar in grid above, it is important to compare it in percentage points to have a better view of the strength of each movement. We can see that in the plot below.

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.plot(sp500_pandemic_2nd['%_Variation'])
ax.plot(nasdaq_pandemic_2nd['%_Variation'])
ax.plot(btc_usd_pandemic_2nd['%_Variation'])
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.vlines(sp500_pandemic_2nd.index.to_frame().loc['3/10/2020'], 
        ymax=5, 
        ymin=-.6, 
        color= 'red', 
        label="Covid-19 Pandemic Declared by WHO", 
        linestyle='solid')
ax.vlines(sp500_pandemic_2nd.index.to_frame().loc['4/8/2020'], 
        ymax=5, 
        ymin=-.6, 
        color= 'black', 
        label="USA sends the 1st stimulus check ($1,000)", 
        linestyle='solid')
ax.vlines(sp500_pandemic_2nd.index.to_frame().loc['12/8/2020'], 
        ymax=5, 
        ymin=-.6, 
        color= 'black', 
        label="USA sends the 2nd stimulus check ($600)", 
        linestyle='dashdot')
ax.vlines(sp500_pandemic_2nd.index.to_frame().loc['3/11/2021'], 
        ymax=5, 
        ymin=-.6, 
        color= 'black', 
        label="USA sends the 3rd stimulus check($1,400)", 
        linestyle='dotted')
ax.legend()

None

# %% [markdown]
# Futhermore, we can get a even better understanding of the price action by analysing how much each asset increased in value <b>using their lows as starting point</b>.

# %%
for asset in post_pandemic_df.columns:
    perf = format(((post_pandemic_df[asset].loc["12/8/2020"] / post_pandemic_df[asset].min())-1) * 100, ".2f")
    print(f'Performance for {asset} from pandemic lows to the 2nd stimulus check: {perf} %')
# Out:
# Performance for BTCUSD from pandemic lows to the 2nd stimulus check: 268.58 %
# Performance for SP500 from pandemic lows to the 2nd stimulus check: 65.47 %
# Performance for NASDAQ100 from pandemic lows to the 2nd stimulus check: 83.40 %

# %%
for asset in post_pandemic_df.columns:
        perf = format(((post_pandemic_df[asset].loc["3/11/2021"] / post_pandemic_df[asset].loc["12/8/2020"])-1) * 100, ".2f")
        print(f'Performance for {asset} from the 2nd stimuls to the 3rd stimulus check: {perf} %')
# Out:
# Performance for BTCUSD from the 2nd stimuls to the 3rd stimulus check: 215.51 %
# Performance for SP500 from the 2nd stimuls to the 3rd stimulus check: 6.40 %
# Performance for NASDAQ100 from the 2nd stimuls to the 3rd stimulus check: 6.48 %

# %%
for asset in post_pandemic_df.columns:
    perf = format(((post_pandemic_df[asset].loc["3/11/2021"] / post_pandemic_df[asset].min())-1) * 100, ".2f")
    print(f'Performance for {asset} from pandemic lows to the 3rd stimulus check: {perf} %')
# Out:
# Performance for BTCUSD from pandemic lows to the 3rd stimulus check: 1062.90 %
# Performance for SP500 from pandemic lows to the 3rd stimulus check: 76.07 %
# Performance for NASDAQ100 from pandemic lows to the 3rd stimulus check: 95.30 %

# %% [markdown]
# As we can see, all risky assets had a great performance from the pandemic lows until people started receiving the 2nd stimulus check. Bitcoin was the best performer and this is understandable since it is way more volatile than stocks.
#
# However, take a look at the performance differences from the 2nd stimulus check to the 3rd stimulus check. In addition, pay attention to the accumulated performance differences from pandemic lows to the third stimulus check.
#
# After analyzing these numbers, we can identify the signs of euphoria in the crypto markets where prices are not aligned to the fundamentals of a security or asset. People are just afraid of missing the new next big run, a phenomenon known as "Fear of Missing Out" or FOMO effect.

# %% [markdown]
# ### The Fear of Missing Out (FOMO) Effect
#
# There is an famous quote in the markets that is often attributed to Mark Twain
#
# <b> "History does not repeat itself, but it rhymes." </b>
#
# The FOMO effect we are seeing now has happened before with NASDAQ, an event that is known by "The Dot-Com Bubble".
#
# Back in late 90s and early 2000s, technology stocks soared higher with the thesis that the internet would be the future of the society.
# That thesis has proven to be true years later. However, the majority of people who invested in technology stocks during that period of euphoria went broke by late 2002 when tech stocks reached their price lows.
#
# Back then, investors saw impressive stock movements upwards. The majority of IPOs were from new technology companies that didn't even generate revenue and people were becoming millionaries so fast that it was hard to hold the emotions and not pour money on technology stocks.
#
# I need to ask to the reader. Does that sounds familiar to you?
#
# Let's go over some data

# %% [markdown]
# #### Dot-Com Bubble Similarities
# Before developing this idea. I have to say that I do believe a FOMO effect has been generated in the stock markets as well but not as intense as it is in the cryptomarkets.
#
# One characteristc of the DotCom Bubble was the sudden creation of new technology companies that didn't have anything other than a powerpoint presentation.
#
# According to CoinMarketCap, the number of <b>listed cryptocurrencies </b> went from 2028 in 2020 to 10263 coins in March, 2022.

# %%
# Number of cryptocurrencies per yaer
years = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
quantity = [7, 67, 501, 572, 636, 1359, 2086, 2403, 4154, 10363]
num_listed_cryptos = pd.DataFrame([years, quantity]).transpose()
num_listed_cryptos.columns = ['Year', 'Number']
num_listed_cryptos = num_listed_cryptos.set_index('Year')

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(num_listed_cryptos.index, num_listed_cryptos['Number'])
ax.set_title("Number of Listed Cryptocurrencies by CoinMarketCap")
plt.xticks(years)
None

# %% [markdown]
# The vast majority of these coins does not have any real functionality, but it seems that this is not an issue for crypto investors.
#
# What seems to be driving investors to pour their money on cryptocurrency is the hope that they will easily become millionaires. In other words, these investors are now greedy enough to pour their money on whatever coin is trending on social media.
#
# Elon Musk's tweets, for example, may had a huge impact on Bitcoin and Dogecoin prices.

# %%
# Bicoin price data (During Pandemic)
btc_usd_fomo = web.DataReader('BTC-USD', data_source='yahoo', start='2020-02-23', end='2021-07-08')['Adj Close'].to_frame().rename(columns={'Adj Close': 'BTCUSD'})
doge_usd_fomo = web.DataReader('DOGE-USD', data_source='yahoo', start='2020-02-23', end='2021-07-08')['Adj Close'].to_frame().rename(columns={'Adj Close': 'BTCUSD'})

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(20, 10))

# Bitcoin Elon Musk Events
ax1.plot(btc_usd_fomo)
ax1.vlines(btc_usd_fomo.index.to_frame().loc['2/7/2021'], 
        ymax=60000, ymin=2500,
        color= 'black', 
        label="Elon Musk Announces Tesla Will Accept Bitcoin as Payment Method", 
        linestyle='dotted') 
ax1.vlines(btc_usd_fomo.index.to_frame().loc['5/12/2021'], 
        ymax=60000, ymin=2500, 
        color= 'red', label="Elon Musk Announces Tesla Will No Longer Accept Bitcoin as Payment Method", 
        linestyle='dotted')
ax1.legend() 


# Dogecoin Elon Musk tweets
ax2.plot(doge_usd_fomo)
ax2.vlines(doge_usd_fomo.index.to_frame().loc['12/20/2020'], ymax=0.7, ymin=0, color= 'black', label="Elon Musk Tweets About Dogecoin", linestyle='dotted')
ax2.vlines(doge_usd_fomo.index.to_frame().loc['2/4/2021'], ymax=0.7, ymin=0, color= 'black', linestyle='dotted')
ax2.vlines(doge_usd_fomo.index.to_frame().loc['4/1/2021'], ymax=0.7, ymin=0, color= 'black', linestyle='dotted')
ax2.vlines(doge_usd_fomo.index.to_frame().loc['4/28/2021'], ymax=0.7, ymin=0, color= 'black', linestyle='dotted')
ax2.vlines(doge_usd_fomo.index.to_frame().loc['5/6/2021'], ymax=0.7, ymin=0, color= 'black', linestyle='dotted')
ax2.legend()

None

# %% [markdown]
# If social media is so relevant to cryptocurrencies, we can also assume that most of its investors have the same age as most of social media users. To make an argument regarding this thesis, I will be analysing the age distribution for the major social media platforms and bitcoin investors.

# %%
instagram_users = pd.read_csv('instagram_users.csv', index_col='Age')
tiktok_users = pd.read_csv('tiktok_users.csv', index_col='Age')
facebook_users = pd.read_csv('facebook_users.csv', index_col='Age')
twitter_users = pd.read_csv('twitter_users.csv', index_col='Age')
bitcoin_investors = pd.read_csv('coin-dance-demographics-age.csv', index_col='Label')

# %%
# Plotting a Pie Chart for the data
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(30, 15))

# Instagram 
ax1.pie(instagram_users['Instagram'], 
    autopct='%1.1f%%',
    pctdistance=.8, 
    labels=instagram_users.index,
    textprops={'color':"w"},
    wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' },
    colors = plt.get_cmap('Blues_r')(np.linspace(0.2, 0.7, len(instagram_users['Instagram']))))
ax1.set_title('Instagram Users by Age')
ax1.legend(loc='upper center', 
           bbox_to_anchor=(0.5, 0.1), ncol=2)

# Facebook
ax2.pie(facebook_users['Facebook'], 
    autopct='%1.1f%%',
    pctdistance=.8, 
    labels=facebook_users.index,
    textprops={'color':"w"},
    wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' },
    colors=plt.get_cmap('Blues_r')(np.linspace(0.2, 0.7, len(facebook_users['Facebook']))))
ax2.set_title('Facebook Users by Age')
ax2.legend(loc='upper center', 
           bbox_to_anchor=(0.5, 0.1), ncol=2)

# TikTok
ax3.pie(tiktok_users['TikTok'], 
    autopct='%1.1f%%',
    pctdistance=.8, 
    labels=tiktok_users.index,
    textprops={'color':"w"},
    wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' },
    colors=plt.get_cmap('Blues_r')(np.linspace(0.2, 0.7, len(tiktok_users['TikTok']))))
ax3.set_title('TikTok Users by Age')
ax3.legend(loc='upper center', 
           bbox_to_anchor=(0.5, 0.1), ncol=2)

# Twitter
ax4.pie(twitter_users['Twitter'], 
    autopct='%1.1f%%',
    pctdistance=.8,
    labels=twitter_users.index,
    textprops={'color':"white"},
    wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' },
    colors=plt.get_cmap('Blues_r')(np.linspace(0.2, 0.7, len(twitter_users['Twitter']))))
ax4.set_title('Twtter Users By Age')
ax4.legend(loc='upper center', 
           bbox_to_anchor=(0.5, 0.1), ncol=2)

#Bitcoin
ax5.pie(bitcoin_investors['Value'],
    autopct='%1.1f%%',
    pctdistance=.8,
    labels=bitcoin_investors.index,
    textprops={'color':'white'},
    wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' },
    colors=plt.get_cmap('Blues_r')(np.linspace(0.2,0.7, len(bitcoin_investors['Value']))))
ax5.set_title('Bitcoin Investors By Age')
ax5.legend(loc='upper center', 
           bbox_to_anchor=(0.5, 0.1), ncol=2)

None

# %% [markdown]
# As we can see, all pie charts share a similar pattern.
#
# The dark blue colors, represented by lower age users, are predominant in all pie charts. This means that most of cryptocurrency investors are social media users and they are more likely to make decisions on what is trending on their favorite platform rether than take time to study and understand what they are putting their money into.
#
# Back in early 2000s there were no social media, still, the idea that people could get rich by investing in the 'future' easily spread throughout society. Who does not want to get super rich and super fast after all?
#
# Social media is full of people pretending to be rich, but this analysis is not about judging people's ethic values. The danger I want to point here is that social media allows information (good or bad) to be shared unimaginably faster than two decades before. The chances are that misinformation and greed have infected the crypto markets and that has trapped people in a fary tale that might not have a happy ending.

# %% [markdown]
# ### Part 3: Analyzing Trading Volume and Price Profile

# %% [markdown]
# To conclude this section. I would like to analyse Bitcoin's Volume and Market Profile.
#
# The Volume Indicator is a very common and well known market indicator that will give a visual representation of the trading activity for a given day.
#
# The Market Profile Indicator is not a common indicator, but it is very useful for identifying relevant price points of a given asset based on the trading volume at a given price. The one I will be using here is an approximation of a Market Profile that will be based on the price trading frequency rether than the actual volume for each price. Even though it is an approximation, we can get very good insights from it.

# %%
# Getting the data needed
btc_price_volume = web.DataReader(
                'BTC-USD',
                data_source='yahoo',
                start='2018-02-01',
                end='2022-06-20'
)
btc_price_volume =  btc_price_volume.drop('2021-02-26') # This specific date shows a volume that is unproportionally greater than in the other days. Dropped assuming this is an error.
btc_price_volume['Volume 200MA'] = btc_price_volume['Volume'].rolling(200).mean()
btc_price_volume = btc_price_volume.dropna()

# %%
# Calculating the Market Profile 

    # scale values and cast to ints
prices = btc_price_volume['Adj Close'].values
x = list(prices)
prices = ((x-min(x)) / (max(x)-min(x))) * 100 + 1


    # create price profile
values = []
counters = []

for price in prices:
    price = int(price)
    values.append(price)
    counters.append(values.count(price))

profile_df = pd.DataFrame({"Value": values, "Index": counters})
btc_price_volume['Close_Scaled'] = prices
mask = btc_price_volume['Volume'] >=  btc_price_volume['Volume 200MA']

# %%
# Plotting the data
    # Price and Market Profile
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(20, 15))
ax1.plot(btc_price_volume.index, btc_price_volume['Close_Scaled'])
ax1.set_ylabel('Scaled Prices')
ax1.grid()

twin_y = ax1.twiny()
twin_y.scatter(profile_df['Index'], profile_df['Value'],s=5, color ='black')
twin_y.set_xlabel('Close Price Frequency')


twin_x = ax1.twinx()
twin_x.plot(btc_price_volume.index, btc_price_volume['Adj Close'])
twin_x.set_ylabel("Actual Close Prices")

ax1.hlines(42, xmax=btc_price_volume.index[-1], xmin=btc_price_volume.index[0], color='black')
ax1.set_title('Bitcoin - Market Profile and Price')

    # Volume
ax2.bar(btc_price_volume.index, btc_price_volume['Volume'], width=2)
ax2.vlines(btc_price_volume[mask].index, ymin=0, ymax=btc_price_volume['Volume'].max(), color = 'black', alpha=0.2)
ax2.plot(btc_price_volume['Volume 200MA'], color ='black')
ax2.set_title('Bitcoin - Daily Volume')
None

# %% [markdown]
# The very first thing to notice here is how important the trading activity was around the USD 10,000 price point. In our data, the most traded area ranges from Bitcoins lows, to the USD 10,000 price mark. Because of that, we can assume that this is a very important price point for Bitcoin. That can be confirmed analyzing the Volume Indicator. We can see that the Bitcoin had a two periods of approximately 6 months of trading volume consistently higher than its 200 Moving Average.
#
# However, the Bitcoin's price increased so fast that the next important trading points ranges from USD 30,000 to USD 60,000. Bitcoin had a very few trading activity around USD 10,000 to USD 30,000. In addition, the trading volume above USD 30,000 mark is significantly higher than the previous periods of high trading valume. One reason that can explain this phenomenom is the huge increase in people's interest for Bitcoin during this exact same period. In the grid below, we can see how the price chart, the volume and the interest for "crypto" in Google Trends share very similar pattern.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(20,10))

ax1.plot(btc_price_volume['Adj Close'])

ax2.plot(stocks_crypto_trend['crypto'])

ax3.bar(btc_price_volume.index, btc_price_volume['Volume'], width=2)

None

# %% [markdown]
# Now let's compare the <b>mean</b> of the volume in 2021 against the volume from past periods to have better idea of the differences among them.

# %%
# Filtering High Trading Volume periods
period_1 = btc_price_volume['Volume'].loc['2019-01-01':'2019-07-01'].mean()
period_2 = btc_price_volume['Volume'].loc['2020-01-01':'2021-07-01'].mean()
period_3 = btc_price_volume['Volume'].loc['2021-01-01':'2021-07-01'].mean()

# %% [markdown]
# <b>2021 Volume vs 2020 Volume</b>

# %%
f'Volume in 2021 was {format(((period_3 / period_2) - 1) * 100, ".2f")}% greater than the Volume in 2020'
# Out:
# 'Volume in 2021 was 42.61% greater than the Volume in 2020'

# %% [markdown]
# <b>2021 Volume vs 2019 Volume </b>

# %%
f'Volume in 2021 was {format(((period_3 / period_1) - 1) * 100, ".2f")}% greater than the Volume in 2019'
# Out:
# 'Volume in 2021 was 327.67% greater than the Volume in 2019'

# %% [markdown]
# After analyzing the Volume and the Price Profile, we can assume that most of the people who invested in Bitcoin in 2021 had an average buy price above USD 30,000.
#
# It is not a coincidence that prices fell very fast when Bitcoin lost it's USD 30,000 price point in June 2022. It is very likely that people's stop-loss were triggered causing a huge sell-off in the asset.
#
# There is one final observation I'd like to make here. Notice how the people's interest towards cryptocurrencies fall when Bitcoin's prices are in a downtrend. It is completely normal to assume that prices of a given asset should increase as more people get interested in that particular asset. However, both variables should not have a strong correlation because the price of a given asset should mirror its intrinsic value rether than the people's interest towards it.
#
# Let's measure the correlation between Bitcoin prices and people's interest for crypto and do the same for stocks.

# %%
# New stock data
sp500_3y = web.DataReader(
                '^GSPC',
                data_source='yahoo',
                start='2019-06-03',
                end='2022-06-06'
)['Adj Close'].to_frame().rename(columns={'Adj Close': 'SP500'})


nasdaq_3y = web.DataReader(
                '^IXIC',
                data_source='yahoo',
                start='2019-06-03',
                end='2022-06-06'
)['Adj Close'].to_frame().rename(columns={'Adj Close': 'NASDAQ100'})


# Importing Google Trends data for 'stocks' and 'crypto'
interest_crypto = pd.read_csv('crypto_search_trends.csv', parse_dates=True, index_col='Week')
interest_stocks = pd.read_csv('stocks_search_trends.csv')


# I had to add one day to the date points because google trends only returns sunday month days
    # Since there is no price data for the given dates this was necessary in order to concatenate both datasets
interest_stocks['Week'] = pd.to_datetime(interest_stocks['Week'])
interest_stocks['Week'] = interest_stocks['Week']+ pd.DateOffset(1) 
interest_stocks = interest_stocks.set_index('Week')

# Building the dataframe for google trends and stocks
interest_vs_price_stocks = pd.concat([
        interest_stocks['stocks'], 
        sp500_3y['SP500'], 
        nasdaq_3y['NASDAQ100']],
        axis=1, 
        join='inner').rename(columns={'stocks': 'Trend_Stocks'})

# Building the dataframe for google trends and crypto
interest_vs_price_bitcoin = pd.concat([
        interest_crypto['crypto'], 
        btc_price_volume['Adj Close']], 
        axis=1,
        join='inner').rename(columns={'crypto':'Trend_Crypto', 'Adj Close': 'BTCUSD'})

# %%
# Measuring Correlation Google Search Trend: Stocks vs SP500 vs NASDAQ100
interest_vs_price_stocks.corr()
# Out:
#               Trend_Stocks     SP500  NASDAQ100
# Trend_Stocks      1.000000  0.029511   0.191118
# SP500             0.029511  1.000000   0.965316
# NASDAQ100         0.191118  0.965316   1.000000

# %%
# Plotting the relationship Google Search: Stocks vs S&P 500
sns.regplot(interest_vs_price_stocks['Trend_Stocks'], interest_vs_price_stocks['SP500'])
plt.title("S&P 500 vs Google Trends: Stocks")
plt.ylabel("S&P 500 Pts")
plt.xlabel("Google Trends: Stocks")
# Out:
# Text(0.5, 0, 'Google Trends: Stocks')

# %%
# Plotting the relationship Google Search: Stocks vs Nasdaq 100
sns.regplot(interest_vs_price_stocks['Trend_Stocks'], interest_vs_price_stocks['NASDAQ100'])
plt.title("S&P 500 vs Google Trends: Stocks")
plt.ylabel("Nasdaq 100 Pts")
plt.xlabel("Google Trends: Stocks")
# Out:
# Text(0.5, 0, 'Google Trends: Stocks')

# %% [markdown]
# As we can see, people's interest for 'stocks' and the prices for the S&P 500 and Nasdaq 100 have a very weak correlation. This is what we would expect under normal circunstances. The plots above shows us that even though prices have been historically high, this does not have an affect on people's interest towards it. Let's see if that is the same for Bitcoin

# %%
# Measuring Correlation: Google Trend Search: Crypto vs Bitcoin Price
interest_vs_price_bitcoin.corr()
# Out:
#               Trend_Crypto    BTCUSD
# Trend_Crypto      1.000000  0.908956
# BTCUSD            0.908956  1.000000

# %%
# Plotting the relationship Google Search: Crypto vs Bitcoin
sns.regplot(interest_vs_price_bitcoin['Trend_Crypto'], interest_vs_price_bitcoin['BTCUSD'])
plt.title("Bitcoin Prices vs Google Trends: Crypto")
plt.ylabel("Bitcoin Prices")
plt.xlabel("Google Trends: Crypto")
# Out:
# Text(0.5, 0, 'Google Trends: Crypto')

# %% [markdown]
# Now we can see how strong the relationship is between people's interest for Bitcoin and it's price. First, the relationship between price and how the word "crypto" trends in Google is very high. Finally, the plot clearly show us that both variables have a strong positive relationship. As price increases, people's interest towards it also increases.

# %% [markdown]
# ## Part 4: "Bitcoin has proven not to be a diversifying asset"

# %% [markdown]
#  This was the exact words of a fund manager (unfortunately I can't remember his name) in a interview for Bloomberg Television and it is so inline with this section that I decided to use as a title.
#
#
#  During the pandemic, cryptocurrency investors (billionaire Ray Dalio was one of them) came up with a thesis that Bitcoin was the "digital gold". What does that really means? I will explain.
#
#  1. Bitcoin and Gold both have scarce supply. Therefore, its value should naturally increase with time as people gets more interested. A basic Supply and Demand thesis.
#  2. Because of the first argument, Bitcoin's price shall not be correlated to risky assets (like stocks), just as gold's price aren't, and it can be used to diversify a investment portfolio.
#  3. Finally, and because of the both arguments above, Bitcoin should be considered as a store of value in times of uncertainty and high inflation. In other words, it is considered as a safe haven asset.
#
# Although the first argument is actually true (Bitcoin's supply is fixed at 21 million), the other two arguments has proven not to be true.

# %% [markdown]
# ### Testing the Argument 2: The Correlation with Risky Assets
#
# To test this argument I will be measuring the correlation among Bitcoin, Stocks (S&P 500 and Nasdaq 100 Indexes), Gold and the 10Y Treasury Yields Futures.
#
# The 10Y Tresury Yields Futures is important in this test because it is often used as a rate of discount in Discounted Cash Flow valuation models. A higher rate of discount will have a negative impact in risky assets price. Even though Bitcoin does not generate cash flows, The 10Y Yield is still relevant because a rise in yields make risky investments less attractive.

# %%
# Importing price data

# Bitcoin price data
btc_usd_5y = web.DataReader('BTC-USD', data_source='yahoo', start='2017-06-23', end='2022-06-22')['Adj Close'].to_frame().rename(columns={'Adj Close': 'BTCUSD'})

# SP500 price data
sp500_5y = web.DataReader('^GSPC', data_source='yahoo', start='2017-06-23', end='2022-06-22')['Adj Close'].to_frame().rename(columns={'Adj Close': 'SP500'})

# NASDAQ 100 price data
nasdaq_5y = web.DataReader('^IXIC', data_source='yahoo', start='2017-06-23', end='2022-06-22')['Adj Close'].to_frame().rename(columns={'Adj Close': 'NASDAQ100'})

# Gold futures price data
gold_usd_5y = web.DataReader('GC=F', data_source='yahoo', start='2017-06-23', end='2022-06-22')['Adj Close'].to_frame().rename(columns={'Adj Close': 'GOLD'})

# 10Y Treasure Bond Yields
treasure_yields_5y = web.DataReader('^TNX', data_source='yahoo', start='2017-06-23', end='2022-06-22')['Adj Close'].to_frame().rename(columns={'Adj Close': '10Y Treasury Yields Fut'})


# Prices Dataframe

prices_df = pd.concat([btc_usd_5y, sp500_5y, nasdaq_5y, gold_usd_5y, treasure_yields_5y], axis=1).dropna()

# %% [markdown]
# Let's begin measuring the correlation for 5 years

# %%
prices_df.corr()
# Out:
#                            BTCUSD     SP500  NASDAQ100      GOLD  \
# BTCUSD                   1.000000  0.913209   0.907342  0.674653
# SP500                    0.913209  1.000000   0.980749  0.808218
# NASDAQ100                0.907342  0.980749   1.000000  0.854878
# GOLD                     0.674653  0.808218   0.854878  1.000000
# 10Y Treasury Yields Fut -0.272943 -0.363903  -0.486497 -0.711243
#
#                          10Y Treasury Yields Fut
# BTCUSD                                 -0.272943
# SP500                                  -0.363903
# NASDAQ100                              -0.486497
# GOLD                                   -0.711243
# 10Y Treasury Yields Fut                 1.000000

# %%
sns.heatmap(prices_df.corr(), cmap="Blues")
plt.title("5 Years Correlation Heatmap")
# Out:
# Text(0.5, 1.0, '5 Years Correlation Heatmap')

# %% [markdown]
# As we can see, besides the 10Y Treasury Futures, during 5 years all markets have been very correlated. Prices from all asset classes have been trending upwards most of the time as markets experienced a historical strong bull market.
#
# However, safe haven assets should shine in period of deep market uncertainty. COVID-19 was a period of uncertainty but because the governments boosted the economy with high doses of steroids, that period of uncertainty didn't last. On the other hand, in 2022 we are facing a true deep market turmoil where inflation is skyrocketing, what is forcing the Federal Reserve to raise interest rates and possibly throwing the economy into recession.
#
# Let's measure the correlation among these assets in 2022

# %%
# Correlation Year-to-Date
prices_df.loc['2022-01-03':].corr()
# Out:
#                            BTCUSD     SP500  NASDAQ100      GOLD  \
# BTCUSD                   1.000000  0.907471   0.897514  0.373130
# SP500                    0.907471  1.000000   0.987375  0.102827
# NASDAQ100                0.897514  0.987375   1.000000  0.077642
# GOLD                     0.373130  0.102827   0.077642  1.000000
# 10Y Treasury Yields Fut -0.661155 -0.731639  -0.790604  0.023262
#
#                          10Y Treasury Yields Fut
# BTCUSD                                 -0.661155
# SP500                                  -0.731639
# NASDAQ100                              -0.790604
# GOLD                                    0.023262
# 10Y Treasury Yields Fut                 1.000000

# %%
sns.heatmap(prices_df.loc['2022-01-03':].corr(), cmap="Blues")
plt.title("2022 Correlation Heatmap")
# Out:
# Text(0.5, 1.0, '2022 Correlation Heatmap')

# %% [markdown]
# According to the analysis, the Gold's correlation to the stock market is near zero, while Bitcoin remained correlated to risky assets. In addition, showing the same behavior as risky assets, the negative correlation with Treasury yields increased drastically for Bitcoin, while the Gold's correlation to yields also remained near zero.
#
# That tackles the argument 2 and we can conclude that Bitcoin <b> does not diversify a investment portfolio </b>

# %% [markdown]
# ## Testing the Argument 3: Bitcoin as Safe Haven and Store of Value
#
# After analyzing the correlation between Bitcoin and other markets, we already have a sense that the crypto cannot be considered as a safe haven asset. However, in order to get better conclusion as if it can be considered as a alternative to store of value, we need to measure its volatility and compare it to other asset classes.
#
# Again, at this point we've seen that the volatility for bitcoin is very high and we could tackle this argument immediately. But let's calculate it and compare it to other markets.

# %%
for asset in prices_df.columns[0:4]:
   print(f'The annualized volatility for {asset} is currently at: {format(((prices_df[asset] / prices_df[asset].shift()).std() * (252 ** (1/2))) * 100, ".2f")}%')
# Out:
# The annualized volatility for BTCUSD is currently at: 78.63%
# The annualized volatility for SP500 is currently at: 20.66%
# The annualized volatility for NASDAQ100 is currently at: 24.07%
# The annualized volatility for GOLD is currently at: 14.84%

# %% [markdown]
# According to the analysis, the volatility for bitcoin is almost four times higher than the volatility for stocks and more five times higher than the volatility for gold.
#
# Because of that, we can also tackle the third argument that states that bitcoin can be use as a safe haven asset and store of value.

# %% [markdown]
# After analyzing both correlation and the volatility for Bitcoin, we can finally conclude that the investor that adds it to the portfolio is actually increasing its the overall risk instead of reducing it.

# %% [markdown]
# ## Part 5: My thoughts On the Short-term and The Long-term of Bitcoin and Cryptos

# %% [markdown]
# ### The Short-term
#
# The year of 2022 has been very challenging to the cryptocurrency markets. According to CoinMarketCap, the total market cap for cryptos is down almost USD 2 trillion from its peak.
#
# My opinion for the short-term is that there is more room for a further decrease in value, because:
#
# 1. The Federal Reserve might have to increase interest rates faster than expected if inflation remains strong. Fact that will probably put the economy into recession and increase the selling pressure in risky assets.
# 2. The recent crash is currently smaller than previous bitcoin's crash in 2017 where less people invested in crypto. Since more people poured money into bitcoin and other cryptocurrencies, we can assume that the capitulation effect (the dramatic surge of selling pressure in a declining market, in other words, when investors literally give up on the security) should be greater than it was experieced before or have the same magnitude.

# %%
# importing CPI data
us_cpi = pd.read_csv('US_CPI.csv').rename(columns={'Country Name' : 'Year', 'United States': 'CPI'}).set_index('Year')
fed_funds = pd.read_csv('FEDFUNDS.csv', parse_dates=True, index_col='DATE')

# Updating last 2022 data
us_cpi.loc[2022] = 8.6

# %% [markdown]
# #### 1. Inflation and Interest Rates
#
# Even though the current euphoric behavior in the crypto markets look very much similar to the DotCom Bubble, the market conditions, on the other hand, are not the same.
#
# Back in 2000s, the U.S. was not facing a major inflation issue and the FED Funds Rate was around 6%. This means that, the FED had enough room to stimulate the economy by lowering interest rates and adopting a dovish monetary policy in case of an economic downturn.
#
# The economic scenario today is way more challenging. Not only the U.S. But the whole world is facing a major inflation problem, what forcing the central banks from major economies to lift interest rates. In order to control inflation, as it faces the highest inflation since December 1981, the U.S. might have to enter in recession by following the same path.

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10,10))

ax1.plot(us_cpi.index, us_cpi['CPI'])
ax1.hlines(
        us_cpi.loc[2000], 
        xmax=us_cpi.index[-1], 
        xmin=us_cpi.index[0], 
        color= 'black',  
        label='Inflation in 2000',
        linestyle='dashdot')
ax1.hlines(
        us_cpi.loc[2022], 
        xmax=us_cpi.index[-1], 
        xmin=us_cpi.index[0], 
        color='red', 
        label='Current Inflation',
        linestyle="dotted")
ax1.hlines(
        2,
        xmax=us_cpi.index[-1],
        xmin=us_cpi.index[0],
        color= 'grey',
        label='FED Inflation Target',
        linestyle="dotted"
)
ax1.legend()
ax1.set_title("U.S. Inflation Rate (1960-2022)")

ax2.plot(fed_funds.index, fed_funds['FEDFUNDS'])
ax2.hlines(
        fed_funds.loc['2000-02-01'], 
        xmax=fed_funds.index[-1], 
        xmin=fed_funds.index[0],
        color='black',
        label='FED Funds Rate in 2000',
        linestyle='dashdot')
ax2.hlines(
        fed_funds.loc['1981-12-01'], 
        xmax=fed_funds.index[-1], 
        xmin=fed_funds.index[0],
        color='red',
        label='FED Funds Rate in December 1981',
        linestyle='dotted'
)
ax2.hlines(
        3,
        xmax=fed_funds.index[-1], 
        xmin=fed_funds.index[0],
        color='grey',
        label="FED Interest Rate target as June 2022",
        linestyle='dotted'
)
ax2.legend()
ax2.set_title("FED Funds Rate (1960-2022)")
# Out:
# Text(0.5, 1.0, 'FED Funds Rate (1960-2022)')

# %% [markdown]
# As I am writing this analysis (June 2022), the Federal Reserve expectation is that a 3.5% interest rate should be able to control the current inflation. However, history shows that to control inflations of similar levels, the FED had to raise interest rates to around 10%, what would be devastating for all risky assets. Of course, many things have changed since 1981, the world is just not the same anymore, however, only time will tell if a 3.5% interest rate will bring inflation back to the FED's 2% target

# %% [markdown]
# #### 2. The Length of the Decline
#
# Back in 2017, Bitcoin also experieced an spectacular sudden increase in value that ended in a great crash. After it reached its previous all time high of USD 19497.40, the crypto tumbled to USD 3236.76 in less than 2 years. This was a decline of 83% from its peak. It is importanto to note that, during that time, there was no COVID-19, no economic crisis, and risky assets were thriving.

# %%
# Calculating the length of the 2017-2018 price movement

peak = btc_usd_5y.loc['2017-06-23':'2019-05-01'].max()
low = btc_usd_5y.loc['2017-10-23':'2019-05-01'].min()
result = format((float((low / peak))-1)*100, ".2f")


f'The length of the crash was {result} %'
# Out:
# 'The length of the crash was -83.40 %'

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.plot(btc_usd_5y.loc['2017-06-23':'2019-04-01'])
ax.hlines(
    np.arange(3200, 19500), 
    xmax=btc_usd_5y.loc['2017-06-23':'2019-05-01'].index[-1], 
    xmin=btc_usd_5y.loc['2017-12-01':'2019-05-01'].index[0], 
    alpha=0.01,
    color='navajowhite',
)
ax.annotate(
        '83.40% Decline from peak', 
        xy=(0.5, 0.6), 
        xycoords='axes fraction',
        fontsize=18)
ax.set_title("Bitcoin Price Chart (2017-2019)")
ax.set_ylabel("Bitcoin Close Prices")

None

# %% [markdown]
# The yellow shaded area represents the price movement from peak to bottom.
#
# In 2022, Bitcoin has suffered a major decline in prices as well. However, this price movement is still weaker than the one we just analyzed. As I stated before, I do belive that if there are many more people invested in Bitcoin, it's capitulation effect should at least have the same magnitude as the previous crash.

# %%
# Calculating the 2022 price movement until 06/22/2022
peak_21 = btc_usd_5y.loc['2021-01-01':].max()
low_22 = btc_usd_5y.loc['2021-01-01':].min()
result_22 = format((float((low_22 / peak_21))-1)*100, ".2f")


f'The length of the crash was {result_22} %'
# Out:
# 'The length of the crash was -71.85 %'

# %%
fig, ax = plt.subplots(figsize=(15,6))
ax.plot(btc_usd_5y.loc['2020-01-01':])
ax.hlines(
    np.arange(19000, 67600), 
    xmax=btc_usd_5y.loc['2021-01-01':].index[-1], 
    xmin=btc_usd_5y.loc['2021-11-01':].index[0], 
    alpha=0.01,
    color='navajowhite',
)
ax.annotate(
    '71.85 % Decline from peak', 
    xy=(0.78, 0.83), 
    xycoords="axes fraction",
    fontsize=10)
ax.set_title("Bitcoin Price Chart (2020-2022)")
ax.set_ylabel("Bitcoin Close Prices")
None

# %% [markdown]
# The yellow shaded are represents the movement from peak to bottom in 2022.
#
# If we assume that the recent price movement will have at least the same magnitude of the decline in 2017 to 2018, there is still room for the movement to continue.

# %%
target = round(peak_21['BTCUSD'] * (1 - 0.834), 2)
pctfall_from_lows = round(((target / low_22['BTCUSD']) - 1) * 100, 2)

f'Assuming same magnitude, Bitcoin prices should reach around USD {target}, which is a {pctfall_from_lows} % decline from previous low'
# Out:
# 'Assuming same magnitude, Bitcoin prices should reach around USD 11216.09, which is a -41.02 % decline from previous low'

# %%
# Plotting Results
fig, ax = plt.subplots(figsize=(15,6))
ax.plot(btc_usd_5y.loc['2020-01-01':])
ax.hlines(
    np.arange(19000, 67600), 
    xmax=btc_usd_5y.loc['2021-01-01':].index[-1], 
    xmin=btc_usd_5y.loc['2021-11-01':].index[0], 
    alpha=0.01,
    color='navajowhite',
)
ax.hlines(
    np.arange(11150,19000),
    xmax=btc_usd_5y.loc['2021-01-01':].index[-1], 
    xmin=btc_usd_5y.loc['2021-11-01':].index[0], 
    alpha=0.01,
    color='salmon'
)
ax.annotate(
    '71.85 % Decline from peak', 
    xy=(0.78, 0.83), 
    xycoords="axes fraction",
    fontsize=10)
ax.annotate(
    'Range to 83.40% Decline',
    xy=(0.758, 0.2),
    xycoords="axes fraction",
    fontsize=10)
ax.set_title("Bitcoin Price Chart (2020-2022)")
None

# %% [markdown]
# The red shaded area represents where the price should fall to if we assume that this movement will have the same magnitude as the previous crash.
#
# Even though the movement looks very small when compared to what has happened in 2022, this is more than 40% decline in prices from Bitcoin's low in 2022.

# %% [markdown]
# ### The Long Term
#
# Even though the short-term looks challenging for Bitcoin, I believe that crypto has a good potential to be the future of society. Never in this study I mentioned that I did not believe in the crypto market, I honestly believe that this world is fascinating and there are very good projects in the horizon.
#
# My opinion is that cryptos must show that society needs it just as the internet showed us in 2000s. However, it is important to keep in mind that the Nasdaq 100 index took more than <b> 15 years </b> to trade above the Bubble DotCom prices. As we can see below

# %%
# NASDAQ 100 price data
nasdaq_2000s = web.DataReader('^IXIC', data_source='yahoo', start='1995-01-01', end='2020-01-01')['Adj Close'].to_frame().rename(columns={'Adj Close': 'NASDAQ100'})

fig, ax = plt.subplots(figsize=(12,6))
ax.plot(nasdaq_2000s['NASDAQ100'])
ax.hlines(np.arange(5049,5051), xmax=nasdaq_2000s.index[5200], xmin=nasdaq_2000s.index[1300], label= 'Nasdaq took more than 15 Years to trade at this level')
ax.annotate("Nasdaq took more than 15 years to trade above this level", xy=(0.3, 0.55), xycoords='axes fraction')
ax.set_title("Nasdaq 100 Price Chart (1995-2020)")
ax.set_ylabel("Nasdaq 100 Pts")
None

# %% [markdown]
# Of course, I don't know what the future will look like.
#
# I don't know if Bitcoin will continue to fall or if it already reached its bottom. I don't know if crypto will be the future of society or it was just a financial party like what happened during the Tulip Mania in 1636.
#
# I would like to emphasize that this study had the purpose of explain what <b>I believe</b> that happened to the crypto market in recent years and the consequences <b>I believe</b> investors may face in the short-term.
#
# Thank you for reading.

# %% [markdown]
# ## Data Sources:
#
# <b>Part 1: Economic Scenario and Risk Sentiment</b>
#
# * [U.S. Quarterly GDP data](https://fred.stlouisfed.org/graph/?g=8eiT)
# * [U.S. Unemployment Rate Data](https://fred.stlouisfed.org/series/UNRATE)
# * [Google Trends: Stocks vs Crypto](https://trends.google.com.br/trends/explore?date=today%205-y&q=stocks,crypto)
# * [Covid-19 Pandemic Timeline](https://www.ajmc.com/view/a-timeline-of-covid19-developments-in-2020)
#
# <b>Part 2: Understanding People's Interest For Bitcoin and Cryptocurrencies</b>
#
# * [Stimulus Check Dates](https://www.usa.gov/covid-stimulus-checks#:~:text=With%20Vaccines.gov-,COVID%2D19%20Stimulus%20Checks%20for%20Individuals,%241%2C400%20in%20March%202021)
# * [Dotcom Bubble](https://www.investopedia.com/terms/d/dotcom-bubble.asp)
# * [Number of Listed Cryptocurrencies](https://explodingtopics.com/blog/number-of-cryptocurrencies)
# * [Bitcoin History Timeline](https://www.tradingview.com/symbols/BTCUSD/history-timeline/)
# * [Dogecoin History Timeline](https://www.tradingview.com/symbols/DOGEUSD/history-timeline/)
# * [Bitcoin Community Engagement](https://coin.dance/stats/age)
# * [Social Media Demographics](https://sproutsocial.com/insights/new-social-media-demographics/)
#
# <b>Part 3: Analyzing Volume and Price Profile</b>
#
# * [Google Trends: Stocks](https://trends.google.com.br/trends/explore?date=today%205-y&q=stocks)
# * [Google Trends: Crypto](https://trends.google.com.br/trends/explore?date=today%205-y&q=crypto)
#
# <b>Part 4: "Bitcoin has proven not to be a diversifying asset"</b>
#
# * [Ray Dalio on Bitcoin as Digital Gold](https://www.cnbc.com/2021/08/04/bitcoin-vs-gold-heres-what-billionaire-ray-dalio-thinks.html)
#
# <b>Part 5: My thoughts On the Short-term and The Long-term of Bitcoin and Cryptos</b>
#
# * [FED Historical Funds Rate](https://fred.stlouisfed.org/series/FEDFUNDS)
# * [U.S. Annual Consumer Price Index Rate](https://data.worldbank.org/indicator/FP.CPI.TOTL.ZG?locations=US)
#
# <b> All Price Data </b>
# * [Yahoo Finance](https://finance.yahoo.com/)
